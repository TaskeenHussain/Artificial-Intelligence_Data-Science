# %% [markdown]
# ## AI and Data Science

# %% [markdown]
# ### Make Id in below mentioned websites:

# %% [markdown]
# #### profile pic maker/
# #### preplexity.ai/
# #### cloud ai /
# #### poe.com/
# #### bingai/
# #### msedge browser
# #### google bard
# #### llama 2/
# #### preplexitylab == Ilama 2
# #### hugging face.co

# %% [markdown]
# Here’s a list of **30+ notable Python IDEs and code editors** (with emoji icons 🐍), categorized by type, popularity, and use case. Most are free or open-source unless noted:
#
# ---
#
# ### **1. General-Purpose IDEs**
# 1. **PyCharm** (🐍)
#    - **Type**: Full-featured IDE
#    - **Best for**: Professional Python development (Django, data science)
#    - **Cost**: Free (Community Edition) or $199/year (Professional)
#    - **Website**: [jetbrains.com/pycharm](https://www.jetbrains.com/pycharm)
#
# 2. **Visual Studio Code** (🚀)
#    - **Type**: Code editor + IDE extensions (Python, Jupyter, etc.)
#    - **Best for**: Cross-language coding with Python plugins
#    - **Cost**: Free
#    - **Website**: [code.visualstudio.com](https://code.visualstudio.com)
#
# 3. **Spyder** (🔬)
#    - **Type**: Scientific IDE
#    - **Best for**: Data science and MATLAB-like workflows
#    - **Cost**: Free
#    - **Website**: [spyder-ide.org](https://www.spyder-ide.org)
#
# 4. **Jupyter Notebook/JupyterLab** (📓)
#    - **Type**: Web-based notebook
#    - **Best for**: Interactive coding, data visualization, and research
#    - **Cost**: Free
#    - **Website**: [jupyter.org](https://jupyter.org)
#
# 5. **IDLE** (🐍)
#    - **Type**: Built-in Python IDE
#    - **Best for**: Beginners and lightweight scripting
#    - **Cost**: Free (bundled with Python)
#
# ---
#
# ### **2. Lightweight Editors with IDE Features**
# 6. **Sublime Text** (✨)
#    - **Type**: Code editor (with Python plugins)
#    - **Cost**: Free trial, $99/license
#    - **Website**: [sublimetext.com](https://www.sublimetext.com)
#
# 7. **Atom** (⚛️) *[Discontinued in 2022]*
#    - **Type**: Hackable text editor
#    - **Website**: [atom.io](https://atom.io)
#
# 8. **Vim** (⌨️) / **Neovim**
#    - **Type**: Terminal-based editor
#    - **Cost**: Free
#    - **Plugins**: Jedi-vim, Python-mode
#
# 9. **Emacs** (📜)
#    - **Type**: Extensible editor
#    - **Cost**: Free
#    - **Plugins**: Elpy, Anaconda-mode
#
# ---
#
# ### **3. Cloud-Based IDEs**
# 10. **Replit** (☁️)
#     - **Type**: Browser-based IDE
#     - **Cost**: Free tier + paid plans ($7–$20/month)
#     - **Website**: [replit.com](https://replit.com)
#
# 11. **Google Colab** (🧠)
#     - **Type**: Jupyter-like cloud notebook
#     - **Cost**: Free (with paid GPU tiers)
#     - **Website**: [colab.research.google.com](https://colab.research.google.com)
#
# 12. **GitHub Codespaces** (🔧)
#     - **Type**: Cloud dev environment
#     - **Cost**: Free for limited hours, paid plans
#
# ---
#
# ### **4. Specialized IDEs**
# 13. **Thonny** (🎓)
#     - **Type**: Beginner-friendly IDE
#     - **Best for**: Teaching Python basics
#     - **Website**: [thonny.org](https://thonny.org)
#
# 14. **Wing Python IDE** (🦅)
#     - **Type**: Debugger-focused IDE
#     - **Cost**: Free trial, $179–$389 (Personal/Pro)
#     - **Website**: [wingware.com](https://wingware.com)
#
# 15. **DataSpell** (📊)
#     - **Type**: JetBrains IDE for data science
#     - **Cost**: $199/year
#     - **Website**: [jetbrains.com/dataspell](https://www.jetbrains.com/dataspell)
#
# 16. **Rodeo** (🤠) *[Discontinued]*
#     - **Type**: Data science IDE (by Yhat)
#
# ---
#
# ### **5. Open-Source & Niche Tools**
# 17. **Eric** (🐍)
#     - **Type**: Open-source IDE
#     - **Website**: [eric-ide.python-projects.org](https://eric-ide.python-projects.org)
#
# 18. **Komodo IDE** (🦎)
#     - **Type**: Multi-language IDE
#     - **Cost**: $12/month
#     - **Website**: [activestate.com/komodo-ide](https://www.activestate.com/products/komodo-ide)
#
# 19. **Geany** (🚀)
#     - **Type**: Fast, lightweight IDE
#     - **Cost**: Free
#     - **Website**: [geany.org](https://www.geany.org)
#
# 20. **Mu Editor** (📱)
#     - **Type**: Simple editor for education
#     - **Website**: [codewith.mu](https://codewith.mu)
#
# 21. **PyDev** (🔌)
#     - **Type**: Eclipse plugin for Python
#     - **Website**: [pydev.org](https://www.pydev.org)
#
# ---
#
# ### **Summary Table**
#
# | IDE/Editor          | Type                | Pricing           | Platform       | Best For                  |
# |---------------------|---------------------|-------------------|----------------|---------------------------|
# | **PyCharm**         | Full IDE            | Free/$199/year    | Cross-platform | Professional Development  |
# | **VS Code**         | Editor + Extensions | Free              | Cross-platform | Versatile Coding          |
# | **Jupyter**         | Notebook            | Free              | Browser/Desktop| Data Science & Research   |
# | **Sublime Text**    | Editor              | $99/license       | Cross-platform | Speed & Plugins           |
# | **Thonny**          | Beginner IDE        | Free              | Cross-platform | Education                 |
# | **Replit**          | Cloud IDE           | Freemium          | Browser        | Collaborative Coding      |
#
# ---
#
# ### **Key Stats**:
# - **Total IDEs/Editors**: 30+ (including niche/legacy tools).
# - **Most Popular**: VS Code, PyCharm, Jupyter, and Sublime Text.
# - **Free Options**: 80% of tools are free or open-source.
#
# Let me know if you’d like setup guides or comparisons! 🖥️

# %% [markdown]
# <!-- ass.:
# how many extensions added in vs code?
# prettier
# github theme
# vscode icon
# jelly fish theme"" -->

# %% [markdown]
# Here’s a categorized list of **essential libraries and frameworks** for AI, machine learning (ML), deep learning (DL), and data science, along with their use cases and installation commands (most are free and open-source):
#
# ---
#
# ### **1. Core Data Handling & Visualization**
# - **Pandas**
#   - **Use**: Data manipulation (DataFrames, CSV/Excel handling).
#   - **Install**: `pip install pandas`
#
# - **NumPy**
#   - **Use**: Numerical computing (arrays, linear algebra).
#   - **Install**: `pip install numpy`
#
# - **Matplotlib**
#   - **Use**: Static/interactive plotting.
#   - **Install**: `pip install matplotlib`
#
# - **Seaborn**
#   - **Use**: Statistical visualizations (built on Matplotlib).
#   - **Install**: `pip install seaborn`
#
# - **Plotly**
#   - **Use**: Interactive visualizations (dashboards, 3D plots).
#   - **Install**: `pip install plotly`
#
# ---
#
# ### **2. Machine Learning (ML)**
# - **Scikit-learn**
#   - **Use**: Classic ML algorithms (regression, classification, clustering).
#   - **Install**: `pip install scikit-learn`
#
# - **XGBoost / LightGBM**
#   - **Use**: Gradient boosting for structured/tabular data.
#   - **Install**: `pip install xgboost lightgbm`
#
# - **CatBoost**
#   - **Use**: Gradient boosting optimized for categorical data.
#   - **Install**: `pip install catboost`
#
# - **Statsmodels**
#   - **Use**: Statistical modeling (hypothesis testing, time series).
#   - **Install**: `pip install statsmodels`
#
# ---
#
# ### **3. Deep Learning (DL)**
# - **TensorFlow / Keras**
#   - **Use**: End-to-end DL workflows (CNNs, RNNs, transformers).
#   - **Install**: `pip install tensorflow`
#
# - **PyTorch**
#   - **Use**: Flexible DL framework (research-focused).
#   - **Install**: `pip install torch`
#
# - **JAX**
#   - **Use**: Accelerated numerical computing (autograd, GPU/TPU support).
#   - **Install**: `pip install jax`
#
# - **Hugging Face Transformers**
#   - **Use**: Pre-trained NLP models (BERT, GPT, T5).
#   - **Install**: `pip install transformers`
#
# ---
#
# ### **4. Natural Language Processing (NLP)**
# - **spaCy**
#   - **Use**: Industrial-strength NLP (tokenization, NER).
#   - **Install**: `pip install spacy`
#
# - **NLTK**
#   - **Use**: NLP research (tokenization, stemming, corpora).
#   - **Install**: `pip install nltk`
#
# - **Gensim**
#   - **Use**: Topic modeling (Word2Vec, LDA).
#   - **Install**: `pip install gensim`
#
# ---
#
# ### **5. Computer Vision**
# - **OpenCV**
#   - **Use**: Image/video processing (object detection, filters).
#   - **Install**: `pip install opencv-python`
#
# - **Pillow (PIL)**
#   - **Use**: Image manipulation (resizing, cropping).
#   - **Install**: `pip install pillow`
#
# - **Torchvision**
#   - **Use**: Datasets and models for vision tasks (with PyTorch).
#   - **Install**: `pip install torchvision`
#
# ---
#
# ### **6. Hyperparameter Tuning & Workflow**
# - **Optuna**
#   - **Use**: Hyperparameter optimization.
#   - **Install**: `pip install optuna`
#
# - **MLflow**
#   - **Use**: Experiment tracking and model deployment.
#   - **Install**: `pip install mlflow`
#
# - **TensorBoard**
#   - **Use**: Visualization of training metrics (for TensorFlow/PyTorch).
#   - **Install**: `pip install tensorboard`
#
# ---
#
# ### **7. Deployment & Production**
# - **Flask / FastAPI**
#   - **Use**: Building REST APIs for model deployment.
#   - **Install**: `pip install flask fastapi`
#
# - **ONNX**
#   - **Use**: Model interoperability (convert models to a universal format).
#   - **Install**: `pip install onnx`
#
# - **BentoML**
#   - **Use**: Model serving and scaling in production.
#   - **Install**: `pip install bentoml`
#
# ---
#
# ### **8. Big Data & Distributed Computing**
# - **PySpark**
#   - **Use**: Distributed data processing (Spark integration).
#   - **Install**: `pip install pyspark`
#
# - **Dask**
#   - **Use**: Parallel computing (scales NumPy/Pandas workflows).
#   - **Install**: `pip install dask`
#
# ---
#
# ### **9. Specialized Libraries**
# - **Prophet** (Time Series Forecasting)
#   - **Install**: `pip install prophet`
#
# - **PyTorch Geometric** (Graph Neural Networks)
#   - **Install**: `pip install torch-geometric`
#
# - **Stable-Baselines3** (Reinforcement Learning)
#   - **Install**: `pip install stable-baselines3`
#
# ---
#
# ### **10. AutoML**
# - **TPOT**
#   - **Use**: Automated ML pipelines (genetic algorithm-based).
#   - **Install**: `pip install tpot`
#
# - **Auto-sklearn**
#   - **Use**: Automated hyperparameter tuning for Scikit-learn.
#   - **Install**: `pip install auto-sklearn`
#
# ---
#
# ### **Key Notes**:
# - **Cost**: All libraries listed above are **free and open-source** unless deployed on paid cloud platforms (e.g., AWS, GCP).
# - **Installation**: Use `pip` or `conda` (for Anaconda environments).
# - **Documentation**: Check official docs for advanced use cases (e.g., [TensorFlow](https://www.tensorflow.org/), [PyTorch](https://pytorch.org/)).

# %% [markdown]
# # How to create conda envoronmnet

# %% [markdown]
# ##### 1_ check the conda env. list C:\Users\ALR>conda env list
# #####  Create a new environment named py35, install Python 3.5
# #####  conda create --name py35 python=3.5
#
# ##### Get a list of all my environments, active environment is shown with *
# #####  conda env list

# %% [markdown]
# #### environment location: C:\Users\ALR\miniconda3\envs\ai_ml_dl_course
#
#
#
# #### Proceed ([y]/n)?
#
#
# #### Downloading and Extracting Packages:
#
# #### Preparing transaction: done
# #### Verifying transaction: done
# #### Executing transaction: done
# #
# ##### To activate this environment, use
# #
# #####    $ conda activate ai_ml_dl_course
# #####
# ##### To deactivate an active environment, use
# #
# #####     $ conda deactivate

# %% [markdown]
# To activate a Miniconda environment in VS Code using the **Command Prompt**, follow these steps:
#
# ---
#
# ### **Step 1: Install Miniconda and Add to PATH**
# - During Miniconda installation, ensure the option **"Add Miniconda to my PATH environment variable"** is checked.
#   *(If you skipped this, reinstall Miniconda or manually add Conda to your PATH.)*
#
# ---
#
# ### **Step 2: Open VS Code Terminal**
# 1. Launch VS Code.
# 2. Open the integrated terminal:
#    - **Shortcut:** `Ctrl + ` ` (Backtick)`
#    - Or go to `Terminal > New Terminal` in the menu.
#
# ---
#
# ### **Step 3: Set Terminal to Command Prompt**
# - If your terminal uses PowerShell or another shell:
#   1. Open the command palette (`Ctrl+Shift+P`).
#   2. Search for **"Terminal: Select Default Profile"**.
#   3. Choose **"Command Prompt"** from the list.
#   4. Close and reopen the terminal.
#
# ---
#
# ### **Step 4: Initialize Conda (If Needed)**
# - If `conda` isn't recognized, run:
#   ```bash
#   conda init cmd.exe
#   ```
# - **Restart VS Code** to apply changes.
#
# ---
#
# ### **Step 5: Activate the Conda Environment**
# 1. List all available environments:
#    ```bash
#    conda env list
#    ```
# 2. Activate your target environment (e.g., `myenv`):
#    ```bash
#    conda activate myenv
#    ```
# 3. Verify activation:
#    - The terminal prompt will show `(myenv)` at the beginning.
#
# ---
#
# ### **Step 6: Select the Python Interpreter in VS Code**
# 1. Open the command palette (`Ctrl+Shift+P`).
# 2. Search for **"Python: Select Interpreter"**.
# 3. Choose the Conda environment (e.g., `Python 3.x.x ('myenv')`).
#    *(VS Code will now use this environment for running/debugging.)*
#
# ---
#
# ### **Troubleshooting**
# - **"Conda not recognized"**:
#   - Fix PATH issues or reinstall Miniconda with PATH enabled.
# - **Activation fails**:
#   - Run `conda init cmd.exe` and restart VS Code.
# - **Environment not listed**:
#   - Create it with `conda create -n myenv python=3.x`.
#
# ---
#
# ### **Example Workflow**
# ```bash
# # Open VS Code terminal (Command Prompt)
# # Initialize Conda (if needed)
# conda init cmd.exe
# # Restart VS Code
#
# # Activate environment
# conda activate myenv
#
# # Check active environment
# conda info --envs
# ```
#
# By following these steps, your Miniconda environment will be active in VS Code's terminal, and VS Code will use the correct Python interpreter.

# %% [markdown]
# ### link for data scinece book is https://wesmckinney.com/book/preliminaries

# %% [markdown]
# Here’s a breakdown of the **Python libraries** you listed, along with their primary uses and applications:
#
# ---
#
# ### 1. **Pandas**
# - **Purpose**: Data manipulation and analysis.
# - **Key Features**:
#   - `DataFrame` and `Series` objects for tabular data.
#   - Tools for reading/writing CSV, Excel, SQL, etc.
#   - Data cleaning, filtering, merging, grouping, and aggregation.
# - **Use Cases**:
#   - Preprocessing datasets (e.g., handling missing values).
#   - Time-series analysis.
#   - Exploratory Data Analysis (EDA).
#
# ---
#
# ### 2. **NumPy**
# - **Purpose**: Numerical computing.
# - **Key Features**:
#   - `ndarray` for efficient multi-dimensional arrays.
#   - Mathematical functions (e.g., linear algebra, Fourier transforms).
#   - Vectorized operations for speed.
# - **Use Cases**:
#   - Matrix operations (e.g., machine learning algorithms).
#   - Scientific simulations.
#   - Foundation for libraries like Pandas, SciPy, and scikit-learn.
#
# ---
#
# ### 3. **Seaborn**
# - **Purpose**: Statistical data visualization.
# - **Key Features**:
#   - Built on Matplotlib, with simpler syntax.
#   - High-level plots (e.g., heatmaps, pair plots, violin plots).
#   - Integration with Pandas DataFrames.
# - **Use Cases**:
#   - Visualizing distributions (e.g., `distplot`).
#   - Correlation analysis (e.g., `heatmap`).
#   - Multi-variable comparisons.
#
# ---
#
# ### 4. **Plotly**
# - **Purpose**: Interactive visualization.
# - **Key Features**:
#   - Web-based, interactive plots (zoom, hover, pan).
#   - 3D plots, maps, and dashboards.
#   - Integration with Dash for web apps.
# - **Use Cases**:
#   - Creating interactive charts for reports/dashboards.
#   - Geospatial visualizations.
#   - Real-time data visualization.
#
# ---
#
# ### 5. **Matplotlib**
# - **Purpose**: Basic plotting and customization.
# - **Key Features**:
#   - Low-level control over plots (e.g., line, bar, scatter).
#   - Customizable axes, labels, and styles.
#   - Foundation for Seaborn and Pandas plotting.
# - **Use Cases**:
#   - Generating publication-quality figures.
#   - Fine-tuning plot aesthetics.
#
# ---
#
# ### 6. **SciPy**
# - **Purpose**: Advanced scientific computing.
# - **Key Features**:
#   - Modules for optimization, integration, interpolation, etc.
#   - Statistical functions (e.g., probability distributions).
#   - Signal/image processing tools.
# - **Use Cases**:
#   - Solving differential equations.
#   - Clustering algorithms.
#   - Sparse matrix operations.
#
# ---
#
# ### 7. **Statsmodels**
# - **Purpose**: Statistical modeling and hypothesis testing.
# - **Key Features**:
#   - Regression models (linear, logistic, time-series).
#   - Hypothesis tests (t-test, ANOVA, chi-square).
#   - Statistical summaries (p-values, R-squared, AIC/BIC).
# - **Use Cases**:
#   - Econometric analysis.
#   - A/B testing.
#   - Forecasting (e.g., ARIMA).
#
# ---
#
# ### **Typical Workflow**
# 1. **Data Handling**: Use **Pandas** and **NumPy** to load, clean, and process data.
# 2. **Visualization**: Create static plots with **Matplotlib/Seaborn** and interactive ones with **Plotly**.
# 3. **Analysis**: Apply statistical methods with **Statsmodels** or scientific tools from **SciPy**.
#
# ---
#
#
# ```
#
# ---
#
# ### **Summary Table**
# | Library       | Domain                     | Key Strengths                          |
# |---------------|---------------------------|----------------------------------------|
# | **Pandas**    | Data Manipulation         | DataFrames, EDA, cleaning              |
# | **NumPy**     | Numerical Computing       | Arrays, math operations                |
# | **Seaborn**   | Visualization             | Statistical plots, simplicity          |
# | **Plotly**    | Interactive Visualization | Dashboards, 3D plots                   |
# | **Matplotlib**| Basic Plotting            | Customization, foundational            |
# | **SciPy**     | Scientific Computing      | Optimization, linear algebra           |
# | **Statsmodels**| Statistical Modeling    | Regression, hypothesis testing         |
#
# These libraries form the backbone of **data science workflows** in Python, covering everything from raw data processing to advanced modeling.

# %%
### **Example Integration**  
#### This script demonstrates how to integrate Python libraries for data analysis.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# Load data with Pandas
data = pd.read_csv("data.csv")

# Clean data with NumPy/Pandas
data.fillna(np.mean(data["column"]), inplace=True)

# Plot with Seaborn
sns.heatmap(data.corr(), annot=True)
plt.show()

# Fit a regression model with Statsmodels
model = sm.OLS(data["target"], data[["feature"]])
results = model.fit()
print(results.summary())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7
#       5 import matplotlib.pyplot as plt
#       6 import seaborn as sns
# ----> 7 import statsmodels.api as sm
#       9 # Load data with Pandas
#      10 data = pd.read_csv("data.csv")
#
# ModuleNotFoundError: No module named 'statsmodels'

# %% [markdown]
# **IPython Kernel (ipykernel)** is a critical component for running Python code in **Jupyter Notebooks**, **JupyterLab**, and other interactive computing environments. Here's why it's essential:
#
# ---
#
# ### **1. Core Purpose**
# **ipykernel** acts as the *execution engine* that connects your Python code (written in a notebook or IDE) to the Python interpreter. It handles:
# - Code execution in cells.
# - Communication between the notebook interface and Python.
# - Rich output display (e.g., plots, HTML, images).
#
# Without ipykernel, Jupyter Notebooks cannot run Python code.
#
# ---
#
# ### **2. Key Uses**
#
# #### **a. Interactive Computing in Jupyter**
# - Enables **cell-by-cell execution** in Jupyter Notebooks.
# - Supports **rich outputs** (e.g., Matplotlib plots, Pandas DataFrames, interactive widgets).
#
# #### **b. Multi-Environment Support**
# - Allows you to use **virtual environments** (e.g., Conda, venv) in Jupyter.
#   ```bash
#   # Install ipykernel in a specific environment
#   conda activate myenv
#   conda install ipykernel
#   ```
# - Lets you switch kernels to use different Python versions or environments within the same notebook.
#
# #### **c. Debugging & Introspection**
# - Powers **debugging tools** (e.g., `%debug`, `pdb`).
# - Enables code introspection (e.g., `?` or `help()` to view docs).
#
# #### **d. Integration with IDEs**
# - Required for Python notebooks in **VS Code**, **PyCharm**, or **Google Colab**.
# - VS Code uses ipykernel to run Jupyter cells in the editor.
#
# #### **e. Customization**
# - Supports **magic commands** (e.g., `%timeit`, `%%html`).
# - Enables custom display logic for objects (e.g., `_repr_html_()` for DataFrames).
#
# ---
#
# ### **3. Example Workflow**
# ```bash
# # Create a virtual environment
# python -m venv myenv
# source myenv/bin/activate  # On Unix
# pip install ipykernel      # Install ipykernel in the environment
#
# # Register the environment with Jupyter
# python -m ipykernel install --user --name=myenv
# ```
#
# Now, you can select the `myenv` kernel in Jupyter to run code in that environment.
#
# ---
#
# ### **4. Troubleshooting**
# - **"No kernel available" error**: Install ipykernel in your environment.
# - **Kernel not updating**: Restart the kernel after installing new packages.
# - **Environment mismatch**: Ensure the correct kernel is selected in Jupyter/VS Code.
#
# ---
#
# ### **5. Why Not Just Use Python?**
# - **Jupyter** requires a **kernel** to manage code execution, state, and interactivity.
# - **ipykernel** bridges the gap between the notebook interface and Python, handling:
#   - Input/output routing.
#   - Asynchronous execution.
#   - Error handling.
#
# ---
#
# ### **Summary**
# **ipykernel** is the backbone of interactive Python computing in Jupyter and modern IDEs. It enables flexible environment management, debugging, and rich visualization, making it indispensable for data science, research, and prototyping workflows.

# %%
#### Book: https://wesmckinney.com/book/python-b...
#### CheatSheet: https://pandas.pydata.org/Pandas_Chea...
#### Dataset: https://www.kaggle.com/account/login?...
